# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# %%
# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.6/dist-packages (1.17.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.6/dist-packages (from geopy) (1.50)
# Collecting folium==0.5.0
#   Downloading https://files.pythonhosted.org/packages/07/37/456fb3699ed23caa0011f8b90d9cad94445eddc656b601e6268090de35f5/folium-0.5.0.tar.gz (79kB)
#      |████████████████████████████████| 81kB 3.4MB/s
# Requirement already satisfied: branca in /usr/local/lib/python3.6/dist-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from folium==0.5.0) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from folium==0.5.0) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->folium==0.5.0) (1.24.3)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.5.0-cp36-none-any.whl size=76240 sha256=708dc156cde2e654c110986cebd0818caad3eb5a93d2a5626089041bfc9030e4
#   Stored in directory: /root/.cache/pip/wheels/f8/98/ff/954791afc47740d554f0d9e5885fa09dd60c2265d42578e665
# Successfully built folium
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.5.0 which is incompatible.
# Installing collected packages: folium
#   Found existing installation: folium 0.8.3
#     Uninstalling folium-0.8.3:
#       Successfully uninstalled folium-0.8.3
# Successfully installed folium-0.5.0

# %%
CLIENT_ID = '5H42MWDW0DLNCI0OEW33NPALECA32I5T0XKHB4KK2CGTHLEX' # your Foursquare ID
CLIENT_SECRET = 'EUTQMVNUZ24OGJJGB30UU10GPM11AQ3C5ICYROTNNWGS1IND' # your Foursquare Secret
ACCESS_TOKEN = 'GQN1Z34SCDKR1TLK3BRG1ZBASTPG3KLKUH51JC0EGGP3011D' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5H42MWDW0DLNCI0OEW33NPALECA32I5T0XKHB4KK2CGTHLEX
# CLIENT_SECRET:EUTQMVNUZ24OGJJGB30UU10GPM11AQ3C5ICYROTNNWGS1IND

# %%
address = '102 North End Ave, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7149555 -74.0153365

# %%
search_query = 'Italian'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=5H42MWDW0DLNCI0OEW33NPALECA32I5T0XKHB4KK2CGTHLEX&client_secret=EUTQMVNUZ24OGJJGB30UU10GPM11AQ3C5ICYROTNNWGS1IND&ll=40.7149555,-74.0153365&oauth_token=GQN1Z34SCDKR1TLK3BRG1ZBASTPG3KLKUH51JC0EGGP3011D&v=20180604&query=Italian&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6024fb9f52faab7f26b07019'},
#  'notifications': [{'item': {'unreadCount': 0}, 'type': 'notificationTray'}],
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'primary': True,
#       'shortName': 'Pizza'}],
#     'hasPerk': False,
#     'id': '4fa862b3e4b0ebff2f749f06',
#     'location': {'address': '225 Murray St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 58,
#      'formattedAddress': ['225 Murray St',
#       'New York, NY 10282',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71521779064671,
#        'lng': -74.01473940209351},
#       {'label': 'entrance', 'lat': 40.715361, 'lng': -74.014975}],
#      'lat': 40.71521779064671,
#      'lng': -74.01473940209351,
#      'postalCode': '10282',
#      'state': 'NY'},
#     'name': "Harry's Italian Pizza Bar",
#     'referralId': 'v-1613036447'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'primary': True,
#       'shortName': 'Food'}],
#     'hasPerk': False,
#     'id': '4f3232e219836c91c7bfde94',
#     'location': {'address': '63 W Broadway',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 469,
#      'formattedAddress': ['63 W Broadway',
#       'New York, NY 10007',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.714484000000006,
#        'lng': -74.00980600000001}],
#      'lat': 40.714484000000006,
#      'lng': -74.00980600000001,
#      'postalCode': '10007',
#      'state': 'NY'},
#     'name': 'Conca Cucina Italian Restaurant',
#     'referralId': 'v-1613036447'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'primary': True,
#       'shortName': 'Italian'}],
#     'hasPerk': False,
#     'id': '3fd66200f964a520f4e41ee3',
#     'location': {'address': '124 Chambers St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'btwn Church St & W Broadway',
#      'distance': 549,
#      'formattedAddress': ['124 Chambers St (btwn Church St & W Broadway)',
#       'New York, NY 10007',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71533713859952,
#        'lng': -74.00884766217825},
#       {'label': 'entrance', 'lat': 40.715202, 'lng': -74.008779}],
#      'lat': 40.71533713859952,
#      'lng': -74.00884766217825,
#      'postalCode': '10007',
#      'state': 'NY'},
#     'name': 'Ecco',
#     'referralId': 'v-1613036447'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id  ...         location.crossStreet
# 0  4fa862b3e4b0ebff2f749f06  ...                          NaN
# 1  4f3232e219836c91c7bfde94  ...                          NaN
# 2  3fd66200f964a520f4e41ee3  ...  btwn Church St & W Broadway
#
# [3 rows x 17 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                               name  ...                        id
# 0        Harry's Italian Pizza Bar  ...  4fa862b3e4b0ebff2f749f06
# 1  Conca Cucina Italian Restaurant  ...  4f3232e219836c91c7bfde94
# 2                             Ecco  ...  3fd66200f964a520f4e41ee3
#
# [3 rows x 15 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
filtered_columns
# Out:
# ['name',
#  'categories',
#  'location.address',
#  'location.lat',
#  'location.lng',
#  'location.labeledLatLngs',
#  'location.distance',
#  'location.postalCode',
#  'location.cc',
#  'location.city',
#  'location.state',
#  'location.country',
#  'location.formattedAddress',
#  'location.crossStreet',
#  'id']

# %%
dataframe_filtered = dataframe.loc[:, filtered_columns]
dataframe_filtered
# Out:
#                               name  ...                        id
# 0        Harry's Italian Pizza Bar  ...  4fa862b3e4b0ebff2f749f06
# 1  Conca Cucina Italian Restaurant  ...  4f3232e219836c91c7bfde94
# 2                             Ecco  ...  3fd66200f964a520f4e41ee3
#
# [3 rows x 15 columns]

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# %%
dataframe_filtered
# Out:
#                               name  ...                        id
# 0        Harry's Italian Pizza Bar  ...  4fa862b3e4b0ebff2f749f06
# 1  Conca Cucina Italian Restaurant  ...  4f3232e219836c91c7bfde94
# 2                             Ecco  ...  3fd66200f964a520f4e41ee3
#
# [3 rows x 15 columns]

# %%
# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                               name  ...                        id
# 0        Harry's Italian Pizza Bar  ...  4fa862b3e4b0ebff2f749f06
# 1  Conca Cucina Italian Restaurant  ...  4f3232e219836c91c7bfde94
# 2                             Ecco  ...  3fd66200f964a520f4e41ee3
#
# [3 rows x 15 columns]

# %%
# Let's visualize the Italian restaurants that are nearby
dataframe_filtered.name
# Out:
# 0          Harry's Italian Pizza Bar
# 1    Conca Cucina Italian Restaurant
# 2                               Ecco
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# %%
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_9d34bf907de94ab5bc5c792a70412da4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9d34bf907de94ab5bc5c792a70412da4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9d34bf907de94ab5bc5c792a70412da4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_9d34bf907de94ab5bc5c792a70412da4%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.7149555%2C-74.0153365%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_9d34bf907de94ab5bc5c792a70412da4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9d34bf907de94ab5bc5c792a70412da4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9d34bf907de94ab5bc5c792a70412da4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_9d34bf907de94ab5bc5c792a70412da4%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.7149555%2C-74.0153365%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## 2. Exploring a Given Venue
#
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %%
venue_id = '4fa862b3e4b0ebff2f749f06' # ID of Harry's Italian Pizza Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4fa862b3e4b0ebff2f749f06?client_id=5H42MWDW0DLNCI0OEW33NPALECA32I5T0XKHB4KK2CGTHLEX&client_secret=EUTQMVNUZ24OGJJGB30UU10GPM11AQ3C5ICYROTNNWGS1IND&oauth_token=GQN1Z34SCDKR1TLK3BRG1ZBASTPG3KLKUH51JC0EGGP3011D&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'like', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])

# %%
result['response']['venue']
# Out:
# {'allowMenuUrlEdit': True,
#  'attributes': {'groups': [{'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}],
#     'name': 'Price',
#     'summary': '$$',
#     'type': 'price'},
#    {'count': 7,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express)'}],
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'type': 'payments'},
#    {'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}],
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'type': 'outdoorSeating'},
#    {'count': 8,
#     'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#      {'displayName': 'Happy Hour', 'displayValue': 'Happy Hour'}],
#     'name': 'Menus',
#     'summary': 'Happy Hour, Brunch & more',
#     'type': 'serves'},
#    {'count': 5,
#     'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#      {'displayName': 'Wine', 'displayValue': 'Wine'},
#      {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}],
#     'name': 'Drinks',
#     'summary': 'Beer, Wine & Cocktails',
#     'type': 'drinks'}]},
#  'beenHere': {'count': 0,
#   'lastCheckinExpiredAt': 0,
#   'marked': False,
#   'unconfirmedCount': 0},
#  'bestPhoto': {'createdAt': 1336776717,
#   'height': 640,
#   'id': '4fad980de4b091b4626c3633',
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'source': {'name': 'Foursquare for Android',
#    'url': 'https://foursquare.com/download/#/android'},
#   'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#   'visibility': 'public',
#   'width': 480},
#  'canonicalUrl': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06',
#  'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d1ca941735',
#    'name': 'Pizza Place',
#    'pluralName': 'Pizza Places',
#    'primary': True,
#    'shortName': 'Pizza'},
#   {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#     'suffix': '.png'},
#    'id': '4bf58dd8d48988d110941735',
#    'name': 'Italian Restaurant',
#    'pluralName': 'Italian Restaurants',
#    'shortName': 'Italian'}],
#  'colors': {'algoVersion': 3,
#   'highlightColor': {'photoId': '4fad980de4b091b4626c3633',
#    'value': -13619152},
#   'highlightTextColor': {'photoId': '4fad980de4b091b4626c3633', 'value': -1}},
#  'contact': {'formattedPhone': '+1 212-608-1007', 'phone': '+12126081007'},
#  'createdAt': 1336435379,
#  'defaultHours': {'dayData': [],
#   'isLocalHoliday': False,
#   'isOpen': False,
#   'richStatus': {'entities': [], 'text': 'Closed until 11:30 AM'},
#   'status': 'Closed until 11:30 AM',
#   'timeframes': [{'days': 'Mon–Wed, Sun',
#     'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu–Sat',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–Midnight'}],
#     'segments': []}]},
#  'dislike': False,
#  'hasMenu': True,
#  'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'},
#  'hours': {'dayData': [],
#   'isLocalHoliday': False,
#   'isOpen': False,
#   'richStatus': {'entities': [], 'text': 'Closed until 11:30 AM'},
#   'status': 'Closed until 11:30 AM',
#   'timeframes': [{'days': 'Mon–Wed, Sun',
#     'open': [{'renderedTime': '11:30 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu–Sat',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:30 AM–Midnight'}],
#     'segments': []}]},
#  'id': '4fa862b3e4b0ebff2f749f06',
#  'inbox': {'count': 0, 'items': []},
#  'like': False,
#  'likes': {'count': 120,
#   'groups': [{'count': 120, 'items': [], 'type': 'others'}],
#   'summary': '120 Likes'},
#  'listed': {'count': 54,
#   'groups': [{'count': 54,
#     'items': [{'canonicalUrl': 'https://foursquare.com/becca_mcarthur/list/manhattan-haunts',
#       'collaborative': False,
#       'createdAt': 1336094672,
#       'description': '',
#       'editable': False,
#       'followers': {'count': 22},
#       'id': '4fa32fd0e4b04193744746b1',
#       'listItems': {'count': 187,
#        'items': [{'createdAt': 1342934485,
#          'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#       'name': 'Manhattan Haunts',
#       'photo': {'createdAt': 1317849414,
#        'height': 330,
#        'id': '4e8cc9461081e3b3544e12e5',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/0NLVU2HC1JF4DXIMKWUFW3QBUT31DC11EFNYYHMJG3NDWAPS.jpg',
#        'user': {'countryCode': 'US',
#         'firstName': 'Time Out New York',
#         'gender': 'none',
#         'id': '742542',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/XXHKCBSQHBORZNSR.jpg'},
#         'type': 'page'},
#        'visibility': 'public',
#        'width': 492},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1380845377,
#       'url': '/becca_mcarthur/list/manhattan-haunts',
#       'user': {'countryCode': 'US',
#        'firstName': 'Becca',
#        'gender': 'female',
#        'id': '24592223',
#        'lastName': 'McArthur',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/24592223-RAW2UYM0GIB1U40K.jpg'}}},
#      {'canonicalUrl': 'https://foursquare.com/kinosfault/list/usa-nyc-man-fidi',
#       'collaborative': False,
#       'createdAt': 1336836475,
#       'description': 'Where to go for decent eats in the restaurant wasteland of Downtown NYC aka FiDi, along with Tribeca & Battery Park City.',
#       'editable': False,
#       'followers': {'count': 20},
#       'id': '4fae817be4b085f6b2a74d19',
#       'listItems': {'count': 273,
#        'items': [{'createdAt': 1373909433,
#          'id': 'v4fa862b3e4b0ebff2f749f06'}]},
#       'name': 'USA NYC MAN FiDi',
#       'photo': {'createdAt': 1436043666,
#        'height': 960,
#        'id': '55984992498e13ba75e353bb',
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/12113441_iOa6Uh-Xi8bhj2-gpzkkw8MKiAIs7RmOcz_RM7m8ink.jpg',
#        'user': {'countryCode': 'US',
#         'firstName': 'Kino',
#         'gender': 'male',
#         'id': '12113441',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}},
#        'visibility': 'public',
#        'width': 540},
#       'public': True,
#       'type': 'others',
#       'updatedAt': 1556754919,
#       'url': '/kinosfault/list/usa-nyc-man-fidi',
#       'user': {'countryCode': 'US',
#        'firstName': 'Kino',
#        'gender': 'male',
#        'id': '12113441',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/12113441-K5HTHFLU2MUCM0CM.jpg'}}}],
#     'name': 'Lists from other people',
#     'type': 'others'}]},
#  'location': {'address': '225 Murray St',
#   'cc': 'US',
#   'city': 'New York',
#   'country': 'United States',
#   'formattedAddress': ['225 Murray St', 'New York, NY 10282', 'United States'],
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.71521779064671,
#     'lng': -74.01473940209351},
#    {'label': 'entrance', 'lat': 40.715361, 'lng': -74.014975}],
#   'lat': 40.71521779064671,
#   'lng': -74.01473940209351,
#   'postalCode': '10282',
#   'state': 'NY'},
#  'menu': {'anchor': 'View Menu',
#   'label': 'Menu',
#   'mobileUrl': 'https://foursquare.com/v/4fa862b3e4b0ebff2f749f06/device_menu',
#   'type': 'Menu',
#   'url': 'https://foursquare.com/v/harrys-italian-pizza-bar/4fa862b3e4b0ebff2f749f06/menu'},
#  'name': "Harry's Italian Pizza Bar",
#  'ok': False,
#  'pageUpdates': {'count': 0, 'items': []},
#  'photos': {'count': 146,
#   'groups': [{'count': 146,
#     'items': [{'createdAt': 1336776717,
#       'height': 640,
#       'id': '4fad980de4b091b4626c3633',
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'source': {'name': 'Foursquare for Android',
#        'url': 'https://foursquare.com/download/#/android'},
#       'suffix': '/ya1iQFI7pLjuIJp1PGDKlrZS3OJdHCF7tpILMmjv_2w.jpg',
#       'user': {'countryCode': 'US',
#        'firstName': 'Leony',
#        'gender': 'none',
#        'id': '13676709',
#        'lastName': 'Naciri',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/T0ANFNGNMCHUDEUE.jpg'}},
#       'visibility': 'public',
#       'width': 480}],
#     'name': 'Venue photos',
#     'type': 'venue'}]},
#  'popular': {'isLocalHoliday': False,
#   'isOpen': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': 'Noon–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '6:00 PM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Tue–Wed',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []}]},
#  'price': {'currency': '$', 'message': 'Moderate', 'tier': 2},
#  'rating': 6.9,
#  'ratingColor': 'FFC800',
#  'ratingSignals': 211,
#  'reasons': {'count': 1,
#   'items': [{'reasonName': 'rawLikesReason',
#     'summary': 'Lots of people like this place',
#     'type': 'general'}]},
#  'seasonalHours': [],
#  'shortUrl': 'http://4sq.com/JNblHV',
#  'specials': {'count': 0, 'items': []},
#  'stats': {'tipCount': 56},
#  'timeZone': 'America/New_York',
#  'tips': {'count': 56,
#   'groups': [{'count': 0,
#     'items': [],
#     'name': 'Tips from people you follow',
#     'type': 'following'},
#    {'count': 56,
#     'items': [{'agreeCount': 3,
#       'canonicalUrl': 'https://foursquare.com/item/53d27909498e0523841340b6',
#       'createdAt': 1406302473,
#       'disagreeCount': 0,
#       'id': '53d27909498e0523841340b6',
#       'like': False,
#       'likes': {'count': 4,
#        'groups': [{'count': 4,
#          'items': [{'countryCode': 'US',
#            'firstName': 'Diane',
#            'gender': 'female',
#            'id': '87587879',
#            'lastName': 'Danneels',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/87587879-ESLRSZLQ2CBE2P4W.jpg'}},
#           {'countryCode': 'US',
#            'firstName': 'Tim',
#            'gender': 'male',
#            'id': '87591341',
#            'lastName': 'Sheehan',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/-Z4YK4VKE0JSVXIY1.jpg'}},
#           {'countryCode': 'US',
#            'firstName': 'TenantKing.com',
#            'gender': 'none',
#            'id': '87473404',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#            'type': 'page'}],
#          'type': 'others'}],
#        'summary': '4 likes'},
#       'logView': True,
#       'text': "Harry's Italian Pizza bar is known for it's amazing pizza, but did you know that the brunches here are amazing too? Try the Nutella French toast and we know you'll be sold.",
#       'todo': {'count': 0},
#       'type': 'user',
#       'user': {'countryCode': 'US',
#        'firstName': 'TenantKing.com',
#        'gender': 'none',
#        'id': '87473404',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/87473404-HI5DTBTK0HX401CA.png'},
#        'type': 'page'}}],
#     'name': 'All tips',
#     'type': 'others'}]},
#  'url': 'http://harrysitalian.com',
#  'verified': False}

# %%
# checking the venue ratings
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.9

# %%
venue_id = '4f3232e219836c91c7bfde94' # ID of Conca Cucina Italian Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '3fd66200f964a520f4e41ee3' # ID of Ecco
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.3

# %%
#since it has better rating
result['response']['venue']['tips']['count']
# Out:
# 19

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6024fba0d8aada4ab55ab38d'},
#  'notifications': [{'item': {'unreadCount': 0}, 'type': 'notificationTray'}],
#  'response': {'tips': {'count': 18,
#    'items': [{'agreeCount': 5,
#      'authorInteractionType': 'liked',
#      'canonicalUrl': 'https://foursquare.com/item/5ab1cb46c9a517174651d3fe',
#      'createdAt': 1521601350,
#      'disagreeCount': 0,
#      'id': '5ab1cb46c9a517174651d3fe',
#      'like': False,
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'text': 'A+ Italian food! Trust me on this: my mom’s side of the family is 100% Italian. I was born and bred to know good pasta when I see it, and Ecco is one of my all-time NYC favorites',
#      'todo': {'count': 0},
#      'type': 'user',
#      'user': {'address': '',
#       'city': '',
#       'firstName': 'Nick',
#       'gender': 'male',
#       'id': '484542633',
#       'lastName': 'El-Tawil',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/484542633_64VpAzxd_1j4zzJ30WhPZsmHMDuV8MDuVX-EkAi2dpa3rHAwENMIZZnAdWajmzXmFL6SegZsB.jpg'},
#       'state': ''}}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'likes', 'like', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered.reindex()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                                                                                                                                                  text  ...    user.id
# 0  A+ Italian food! Trust me on this: my mom’s side of the family is 100% Italian. I was born and bred to know good pasta when I see it, and Ecco is one of my all-time NYC favorites  ...  484542633
#
# [1 rows x 7 columns]

# %%
#searching for a foursquare user 
idnumber = '48454224' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}'.format(idnumber, CLIENT_ID, CLIENT_SECRET, ACCESS_TOKEN,VERSION) # define URL

# send GET request
results = requests.get(url).json()
#user_data = results['response']['user']
user_data=results['response']['tips']['items'][0]['venue']['photos']['groups'][0]['items']#['items']
# display features associated with user
#user_data.keys()
#results
pd.set_option('display.max_colwidth', -1)

users_df = json_normalize(user_data)

# filter columns
filtered_columns = ['id','user.id','user.firstName','user.lastName']
tips_filtered = users_df.loc[:, filtered_columns]

# display user's tips
df=tips_filtered
df
#url
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   from ipykernel import kernelapp as app
#                          id    user.id user.firstName     user.lastName
# 0  57099084498e6e5b94d5a312  133773133  Cesar          H. Gamboa
# 1  541e1d3b498e8e793290f7cd  30238440   Cesar          H. Gamboa
# 2  53cb1c82498ef31f2f2eba34  51713900   Marcs          Marquez Mejorada

# %%
g=df.loc[df['user.id'] == '133773133']
print('First Name: ' + g['user.firstName'])
print('Last Name: ' + g['user.lastName'])
# Out:
# 0    First Name: Cesar
# Name: user.firstName, dtype: object
# 0    Last Name: H. Gamboa
# Name: user.lastName, dtype: object

# %%
# 1. grab prefix of photo
# 2. grab suffix of photo
# 3. concatenate them using the image size  
Image(url='https://fastly.4sqi.net/img/general/540x920/133773133_ODR5Au05ENkSyu3xxfV3VOfCa0idDfm9Q4n8YbhZDRQ.jpg')
# Out:
# <img src="https://fastly.4sqi.net/img/general/540x920/133773133_ODR5Au05ENkSyu3xxfV3VOfCa0idDfm9Q4n8YbhZDRQ.jpg"/>

# %%
# define tips URL
user_id='484542633'
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN,VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if sys.path[0] == '':
#                                                                                                                                   text  ...                        id
# 0   You’re not a real New Yorker until you’ve shame-ordered Insomnia Cookies for delivery at 3am                                        ...  5acbbd4eb1538e45373b07f5
# 1   Good for you yet still tasty! Clean green protein is my go-to after I hit the gym 💪                                                 ...  5acbbcda01235808d5d6dc75
# 2   Burger game strong 💪                                                                                                                ...  5ab575fb6bdee65f759da8c1
# 3   Great burgers & fries! Also, this place is exactly what it’s like when you go to a bar in the Southwest. Source: I’m from Arizona.  ...  5ab5575d73fe2516ad8f363b
# 4   Açaí bowl + peanut butter + whey protein = 💪💪💪                                                                                      ...  5ab42db53c858d64af2688a4
# 5   Highly underrated and way less crowded than Central Park!                                                                           ...  5ab42c396f706a29f53ad1a8
# 6   Get the açaí bowl with peanut butter after your work out and thank me later 👌                                                       ...  5ab42aca2a7ab6333652b266
# 7   When you want a burger, this should be the first thing that comes to mind. A+!                                                      ...  5ab42a28da5e5617d18e3a6a
# 8   Way less crowded than Central Park! People who live in the neighborhood rave about Carl Schurz Park.                                ...  5ab429db1ffe971b060083f5
# 9   The best Mexican food in the Murray Hill / Kips Bay area!                                                                           ...  5ab3f53f8496ca57542d5549
# 10  Best coffee shop in the neighborhood!                                                                                               ...  5ab3f428da5e5617d17d1475
# 11  When there’s nice weather, the rooftop at Tonic East is the best place to watch the game. Perfect for March Madness & NBA finals!   ...  5ab3f3fedd70c572de886c9d
# 12  Rib game level 💯                                                                                                                    ...  5ab3f372da2e00604ca53924
# 13  Solid option for good Mexican food, which is hard to find in Murray Hill.                                                           ...  5ab3f275dff815096a61884e
# 14  So good it makes me burp after every meal. I’ve been told that’s a compliment in France, so I’m going to keep doing it 🇫🇷           ...  5ab3e8d6d0336060272dd4d9
#
# [15 rows x 4 columns]

# %%
tip_id = '5ab5575d73fe2516ad8f363b' # tip id

# define URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}'.format(idnumber, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION) # define URL


# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tips']['items'][0]['venue']['name'])
print(result['response']['tips']['items'][0]['venue']['location'])
# Out:
# Tres Bar
# {'lat': 20.17693758560229, 'lng': -98.04832423694748, 'labeledLatLngs': [{'label': 'display', 'lat': 20.17693758560229, 'lng': -98.04832423694748}], 'cc': 'MX', 'country': 'México', 'formattedAddress': ['México']}

# %%
# Exploring the nearby areas
latitude = 40.715337
longitude = -74.008848

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=5H42MWDW0DLNCI0OEW33NPALECA32I5T0XKHB4KK2CGTHLEX&client_secret=EUTQMVNUZ24OGJJGB30UU10GPM11AQ3C5ICYROTNNWGS1IND&ll=40.715337,-74.008848&v=20180604&radius=500&limit=30'

# %%
results = requests.get(url).json()
'There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Ecco restaurant.'

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '6024fcf02776b86a580d8199'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5d5f24ec09484500079aee00-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'primary': True,
#          'shortName': 'Tacos'}],
#        'delivery': {'id': '2180700',
#         'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'seamless'},
#         'url': 'https://www.seamless.com/menu/los-tacos-no-1-tribeca-136-church-st-new-york/2180700?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2180700'},
#        'id': '5d5f24ec09484500079aee00',
#        'location': {'address': '136 Church St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'distance': 119,
#         'formattedAddress': ['136 Church St',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.714267,
#           'lng': -74.008756}],
#         'lat': 40.714267,
#         'lng': -74.008756,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Los Tacos No. 1',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af5d65ff964a52091fd21e3-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'primary': True,
#          'shortName': 'Furniture / Home'}],
#        'id': '4af5d65ff964a52091fd21e3',
#        'location': {'address': '57 Warren St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'Church St',
#         'distance': 73,
#         'formattedAddress': ['57 Warren St (Church St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71482437714839,
#           'lng': -74.00940425461492},
#          {'label': 'entrance', 'lat': 40.714727, 'lng': -74.009399}],
#         'lat': 40.71482437714839,
#         'lng': -74.00940425461492,
#         'neighborhood': 'Tribeca',
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Korin',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33104775'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c154c9a77cea593c401d260-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '4c154c9a77cea593c401d260',
#        'location': {'address': '25 Murray St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Church St',
#         'distance': 187,
#         'formattedAddress': ['25 Murray St (at Church St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.713652845301894,
#           'lng': -74.0088038953017},
#          {'label': 'entrance', 'lat': 40.713716, 'lng': -74.008443}],
#         'lat': 40.713652845301894,
#         'lng': -74.0088038953017,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Takahachi Bakery',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '85495566'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54148bc6498ea7bb8c05b70a-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'primary': True,
#          'shortName': 'Vegetarian / Vegan'}],
#        'id': '54148bc6498ea7bb8c05b70a',
#        'location': {'address': '83 Murray St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn Greenwich St & W Broadway',
#         'distance': 202,
#         'formattedAddress': ['83 Murray St (btwn Greenwich St & W Broadway)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71478769908051,
#           'lng': -74.0111317502157}],
#         'lat': 40.71478769908051,
#         'lng': -74.0111317502157,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Juice Press',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57ad129c498e05b086594d72-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'primary': True,
#          'shortName': 'Spa'}],
#        'id': '57ad129c498e05b086594d72',
#        'location': {'address': '92 Reade St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'distance': 100,
#         'formattedAddress': ['92 Reade St',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.715726,
#           'lng': -74.007767},
#          {'label': 'entrance', 'lat': 40.715654, 'lng': -74.00782}],
#         'lat': 40.715726,
#         'lng': -74.007767,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Heyday',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4a8f2f39f964a520471420e3-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'primary': True,
#          'shortName': 'Sushi'}],
#        'id': '4a8f2f39f964a520471420e3',
#        'location': {'address': '145 Duane St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn W Broadway & Church St',
#         'distance': 146,
#         'formattedAddress': ['145 Duane St (btwn W Broadway & Church St)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71652647412374,
#           'lng': -74.00810108466207},
#          {'label': 'entrance', 'lat': 40.716508, 'lng': -74.007989}],
#         'lat': 40.71652647412374,
#         'lng': -74.00810108466207,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Takahachi',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4adcf23cf964a520cc6221e3-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d119951735',
#          'name': 'Wine Shop',
#          'pluralName': 'Wine Shops',
#          'primary': True,
#          'shortName': 'Wine Shop'}],
#        'id': '4adcf23cf964a520cc6221e3',
#        'location': {'address': '148 Chambers St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn West Broadway & Hudson St',
#         'distance': 88,
#         'formattedAddress': ['148 Chambers St (btwn West Broadway & Hudson St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.715773063928374,
#           'lng': -74.00971823312332},
#          {'label': 'entrance', 'lat': 40.715696, 'lng': -74.00988}],
#         'lat': 40.715773063928374,
#         'lng': -74.00971823312332,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Chambers Street Wines',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5dc6f6a5ea8dfb00080f6faa-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'primary': True,
#          'shortName': 'Burgers'}],
#        'delivery': {'id': '2407406',
#         'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'seamless'},
#         'url': 'https://www.seamless.com/menu/lekka-burger-81-warren-st-new-york/2407406?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2407406'},
#        'id': '5dc6f6a5ea8dfb00080f6faa',
#        'location': {'address': '81 Warren St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btw Greenwich & West Broadway',
#         'distance': 144,
#         'formattedAddress': ['81 Warren St (btw Greenwich & West Broadway)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.715246,
#           'lng': -74.010559}],
#         'lat': 40.715246,
#         'lng': -74.010559,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Lekka Burger',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4a6e331af964a52031d41fe3-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4a6e331af964a52031d41fe3',
#        'location': {'address': '54 Murray St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at W Broadway',
#         'distance': 154,
#         'formattedAddress': ['54 Murray St (at W Broadway)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71409860726041,
#           'lng': -74.0096857179283}],
#         'lat': 40.71409860726041,
#         'lng': -74.0096857179283,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Equinox Tribeca',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cd89eeb6e8b5941660c64d2-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'delivery': {'id': '2486305',
#         'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'seamless'},
#         'url': 'https://www.seamless.com/menu/weather-up-159-duane-st-new-york/2486305?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2486305'},
#        'id': '4cd89eeb6e8b5941660c64d2',
#        'location': {'address': '159 Duane St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn Hudson St. & W Broadway',
#         'distance': 157,
#         'formattedAddress': ['159 Duane St (btwn Hudson St. & W Broadway)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71674084163369,
#           'lng': -74.0086664438893},
#          {'label': 'entrance', 'lat': 40.71685, 'lng': -74.008729}],
#         'lat': 40.71674084163369,
#         'lng': -74.0086664438893,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Weather Up',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-49bc3b0af964a52020541fe3-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '49bc3b0af964a52020541fe3',
#        'location': {'address': '270 Greenwich Street',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Warren St',
#         'distance': 214,
#         'formattedAddress': ['270 Greenwich Street (at Warren St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.715579155420606,
#           'lng': -74.01136823958119}],
#         'lat': 40.715579155420606,
#         'lng': -74.01136823958119,
#         'neighborhood': 'Tribeca',
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Whole Foods Market',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b747291f964a52042dd2de3-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d116951735',
#          'name': 'Antique Shop',
#          'pluralName': 'Antique Shops',
#          'primary': True,
#          'shortName': 'Antiques'}],
#        'id': '4b747291f964a52042dd2de3',
#        'location': {'address': '122 Chambers St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'distance': 8,
#         'formattedAddress': ['122 Chambers St',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71528423132827,
#           'lng': -74.00878093952018},
#          {'label': 'entrance', 'lat': 40.715188, 'lng': -74.008747}],
#         'lat': 40.71528423132827,
#         'lng': -74.00878093952018,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Philip Williams Posters',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50ba9119e4b071a4bae6dc10-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10b941735',
#          'name': 'Falafel Restaurant',
#          'pluralName': 'Falafel Restaurants',
#          'primary': True,
#          'shortName': 'Falafel'}],
#        'id': '50ba9119e4b071a4bae6dc10',
#        'location': {'address': '88 Reade St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Church St',
#         'distance': 97,
#         'formattedAddress': ['88 Reade St (at Church St)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71553710116416,
#           'lng': -74.00772452925565},
#          {'label': 'entrance', 'lat': 40.715615, 'lng': -74.00773}],
#         'lat': 40.71553710116416,
#         'lng': -74.00772452925565,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Nish Nūsh',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '93083181'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51df85c9498edb5ea3ad2e2a-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'delivery': {'id': '1983382',
#         'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'seamless'},
#         'url': 'https://www.seamless.com/menu/khe-yo-157-duane-st-new-york/1983382?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1983382'},
#        'id': '51df85c9498edb5ea3ad2e2a',
#        'location': {'address': '157 Duane Street',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn Hudson St & W Broadway',
#         'distance': 159,
#         'formattedAddress': ['157 Duane Street (btwn Hudson St & W Broadway)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.716752816876635,
#           'lng': -74.00858376295221}],
#         'lat': 40.716752816876635,
#         'lng': -74.00858376295221,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Khe-Yo',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '350356912'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-3fd66200f964a52083e61ee3-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'primary': True,
#          'shortName': 'French'}],
#        'id': '3fd66200f964a52083e61ee3',
#        'location': {'address': '145 W Broadway',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Thomas St',
#         'distance': 198,
#         'formattedAddress': ['145 W Broadway (at Thomas St)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71701011409906,
#           'lng': -74.00804244562225}],
#         'lat': 40.71701011409906,
#         'lng': -74.00804244562225,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'The Odeon',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '97281190'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dadcb124df0522cc5622202-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'delivery': {'id': '2236902',
#         'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'seamless'},
#         'url': 'https://www.seamless.com/menu/tinys--the-bar-upstairs-135-west-broadway-new-york/2236902?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2236902'},
#        'id': '4dadcb124df0522cc5622202',
#        'location': {'address': '135 W Broadway',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'between Duane St & Thomas St',
#         'distance': 170,
#         'formattedAddress': ['135 W Broadway (between Duane St & Thomas St)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71679304855808,
#           'lng': -74.00821998878457}],
#         'lat': 40.71679304855808,
#         'lng': -74.00821998878457,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': "Tiny's and the Bar Upstairs",
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '84453413'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-534c9d7b498e1bdd443a40e1-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'primary': True,
#          'shortName': 'French'}],
#        'id': '534c9d7b498e1bdd443a40e1',
#        'location': {'address': '94 Chambers St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'distance': 125,
#         'formattedAddress': ['94 Chambers St',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.714754151461236,
#           'lng': -74.0075806002039}],
#         'lat': 40.714754151461236,
#         'lng': -74.0075806002039,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Racines',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-545c0436498e798e22ce4b2a-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'id': '545c0436498e798e22ce4b2a',
#        'location': {'address': '85 W Broadway',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Chambers St',
#         'distance': 29,
#         'formattedAddress': ['85 W Broadway (at Chambers St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.715486585249735,
#           'lng': -74.00913313510836},
#          {'label': 'entrance', 'lat': 40.715227, 'lng': -74.009263}],
#         'lat': 40.715486585249735,
#         'lng': -74.00913313510836,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Little Park',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '102902274'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c3cb549b36ac9285d7a0486-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4c3cb549b36ac9285d7a0486',
#        'location': {'address': 'Duane St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Hudson St',
#         'distance': 208,
#         'formattedAddress': ['Duane St (at Hudson St)',
#          'New York, NY',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71717275801168,
#           'lng': -74.00932869125117}],
#         'lat': 40.71717275801168,
#         'lng': -74.00932869125117,
#         'state': 'NY'},
#        'name': 'Duane Park',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b8dbba4f964a5201e0b33e3-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b47',
#          'name': 'Boxing Gym',
#          'pluralName': 'Boxing Gyms',
#          'primary': True,
#          'shortName': 'Boxing Gym'}],
#        'id': '4b8dbba4f964a5201e0b33e3',
#        'location': {'address': '25 Park Pl',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn Church St. & Broadway',
#         'distance': 221,
#         'formattedAddress': ['25 Park Pl (btwn Church St. & Broadway)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.713353574017404,
#           'lng': -74.00906676030888}],
#         'lat': 40.713353574017404,
#         'lng': -74.00906676030888,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Church Street Boxing Gym',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4a9bcc2ff964a5203b3520e3-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'primary': True,
#          'shortName': 'Playground'}],
#        'id': '4a9bcc2ff964a5203b3520e3',
#        'location': {'address': 'Greenwich St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Reade St',
#         'distance': 268,
#         'formattedAddress': ['Greenwich St (at Reade St)',
#          'New York, NY',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71704598853704,
#           'lng': -74.01109457015991}],
#         'lat': 40.71704598853704,
#         'lng': -74.01109457015991,
#         'state': 'NY'},
#        'name': 'Washington Market Park',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-49ccd495f964a52091591fe3-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '49ccd495f964a52091591fe3',
#        'location': {'address': '275 Greenwich St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Murray St',
#         'distance': 226,
#         'formattedAddress': ['275 Greenwich St (at Murray St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71504512558996,
#           'lng': -74.0115087102821}],
#         'lat': 40.71504512558996,
#         'lng': -74.0115087102821,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Kaffe 1668',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '43231093'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ea0afbf9adf1e334e4cc0e6-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'delivery': {'id': '2074742',
#         'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'seamless'},
#         'url': 'https://www.seamless.com/menu/laughing-man-coffee--tea-co-184-duane-street-new-york/2074742?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2074742'},
#        'id': '4ea0afbf9adf1e334e4cc0e6',
#        'location': {'address': '184 Duane St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn Greenwich & Hudson St.',
#         'distance': 252,
#         'formattedAddress': ['184 Duane St (btwn Greenwich & Hudson St.)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7173944529165,
#           'lng': -74.01010324607125}],
#         'lat': 40.7173944529165,
#         'lng': -74.01010324607125,
#         'neighborhood': 'Tribeca',
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Laughing Man Coffee & Tea',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '73541580'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4a8c4baef964a520960d20e3-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'primary': True,
#          'shortName': "Farmer's Market"}],
#        'id': '4a8c4baef964a520960d20e3',
#        'location': {'address': 'Greenwich St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btw Chambers St & Duane St',
#         'distance': 236,
#         'formattedAddress': ['Greenwich St (btw Chambers St & Duane St)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.716802033574126,
#           'lng': -74.01087999343872}],
#         'lat': 40.716802033574126,
#         'lng': -74.01087999343872,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Tribeca Greenmarket',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4a4baaf8f964a52091ac1fe3-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d179941735',
#          'name': 'Bagel Shop',
#          'pluralName': 'Bagel Shops',
#          'primary': True,
#          'shortName': 'Bagels'}],
#        'delivery': {'id': '277435',
#         'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'seamless'},
#         'url': 'https://www.seamless.com/menu/zuckers-bagels--smoked-fish-146-chambers-st-new-york/277435?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=277435'},
#        'id': '4a4baaf8f964a52091ac1fe3',
#        'location': {'address': '146 Chambers St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'btwn W. Broadway & Greenwich St',
#         'distance': 88,
#         'formattedAddress': ['146 Chambers St (btwn W. Broadway & Greenwich St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71558,
#           'lng': -74.00985}],
#         'lat': 40.71558,
#         'lng': -74.00985,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': "Zucker's Bagels & Smoked Fish",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-437bc800f964a520a52a1fe3-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'delivery': {'id': '2099714',
#         'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'seamless'},
#         'url': 'https://www.seamless.com/menu/scalini-fedeli-165-duane-street-new-york/2099714?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2099714'},
#        'id': '437bc800f964a520a52a1fe3',
#        'location': {'address': '165 Duane St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Hudson',
#         'distance': 216,
#         'formattedAddress': ['165 Duane St (at Hudson)',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71722617263501,
#           'lng': -74.00943297013102}],
#         'lat': 40.71722617263501,
#         'lng': -74.00943297013102,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Scalini Fedeli',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e31c3b1814d9a6fbde557c7-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d101941735',
#          'name': 'Martial Arts School',
#          'pluralName': 'Martial Arts Schools',
#          'primary': True,
#          'shortName': 'Martial Arts'}],
#        'id': '4e31c3b1814d9a6fbde557c7',
#        'location': {'address': '78 Reade St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'at Church St & Broadway',
#         'distance': 125,
#         'formattedAddress': ['78 Reade St (at Church St & Broadway)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71543099173628,
#           'lng': -74.00736173096483}],
#         'lat': 40.71543099173628,
#         'lng': -74.00736173096483,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Modern Martial Arts NYC Tribeca',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-49efcc88f964a52006691fe3-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '49efcc88f964a52006691fe3',
#        'location': {'address': '85 W Broadway',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'crossStreet': 'Chambers St',
#         'distance': 35,
#         'formattedAddress': ['85 W Broadway (Chambers St)',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7151439,
#           'lng': -74.0091826}],
#         'lat': 40.7151439,
#         'lng': -74.0091826,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'Smyth Hotel',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5f874da162878a7c65fe2fa3-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '5f874da162878a7c65fe2fa3',
#        'location': {'address': '220 Church St',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'distance': 250,
#         'formattedAddress': ['220 Church St',
#          'New York, NY 10013',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.716844,
#           'lng': -74.006648}],
#         'lat': 40.716844,
#         'lng': -74.006648,
#         'postalCode': '10013',
#         'state': 'NY'},
#        'name': 'Frenchette Bakery',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58a253c830ecc66c9e5b40a0-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '58a253c830ecc66c9e5b40a0',
#        'location': {'address': '22 Park Pl',
#         'cc': 'US',
#         'city': 'New York',
#         'country': 'United States',
#         'distance': 287,
#         'formattedAddress': ['22 Park Pl',
#          'New York, NY 10007',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.71275251771485,
#           'lng': -74.00873355601571},
#          {'label': 'entrance', 'lat': 40.712781, 'lng': -74.008548}],
#         'lat': 40.71275251771485,
#         'lng': -74.00873355601571,
#         'postalCode': '10007',
#         'state': 'NY'},
#        'name': 'The Class by Taryn Toomey',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Tribeca, New York',
#   'headerLocation': 'Tribeca',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 40.7198370045, 'lng': -74.00292208843348},
#    'sw': {'lat': 40.710836995499996, 'lng': -74.01477391156652}},
#   'suggestedFilters': {'filters': [{'key': 'price', 'name': '$-$$$$'},
#     {'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 125}}

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'reasonName': 'globalInteractionReason',
#     'summary': 'This spot is popular',
#     'type': 'general'}]},
#  'referralId': 'e-0-5d5f24ec09484500079aee00-0',
#  'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#      'suffix': '.png'},
#     'id': '4bf58dd8d48988d151941735',
#     'name': 'Taco Place',
#     'pluralName': 'Taco Places',
#     'primary': True,
#     'shortName': 'Tacos'}],
#   'delivery': {'id': '2180700',
#    'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#      'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50]},
#     'name': 'seamless'},
#    'url': 'https://www.seamless.com/menu/los-tacos-no-1-tribeca-136-church-st-new-york/2180700?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2180700'},
#   'id': '5d5f24ec09484500079aee00',
#   'location': {'address': '136 Church St',
#    'cc': 'US',
#    'city': 'New York',
#    'country': 'United States',
#    'distance': 119,
#    'formattedAddress': ['136 Church St',
#     'New York, NY 10007',
#     'United States'],
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.714267,
#      'lng': -74.008756}],
#    'lat': 40.714267,
#    'lng': -74.008756,
#    'postalCode': '10007',
#    'state': 'NY'},
#   'name': 'Los Tacos No. 1',
#   'photos': {'count': 0, 'groups': []}}}

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                     name  ...                        id
# 0  Los Tacos No. 1        ...  5d5f24ec09484500079aee00
# 1  Korin                  ...  4af5d65ff964a52091fd21e3
# 2  Takahachi Bakery       ...  4c154c9a77cea593c401d260
# 3  Juice Press            ...  54148bc6498ea7bb8c05b70a
# 4  Heyday                 ...  57ad129c498e05b086594d72
# 5  Takahachi              ...  4a8f2f39f964a520471420e3
# 6  Chambers Street Wines  ...  4adcf23cf964a520cc6221e3
# 7  Lekka Burger           ...  5dc6f6a5ea8dfb00080f6faa
# 8  Equinox Tribeca        ...  4a6e331af964a52031d41fe3
# 9  Weather Up             ...  4cd89eeb6e8b5941660c64d2
#
# [10 rows x 16 columns]

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_defea3249d0548329b4b377413927743%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_defea3249d0548329b4b377413927743%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_defea3249d0548329b4b377413927743%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_defea3249d0548329b4b377413927743%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.715337%2C-74.008848%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %%
#Exploring trending venue
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6024fd8b2dbbf54b000dae28'},
#  'response': {'venues': []}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'
